# %% [markdown]
# # Week 15, Lecture 02 CodeAlong: Hypothesis Testing

# %% [markdown]
# - 06/08/22

# %% [markdown]
# Today, we will be analyzing data from the Crowdfunding website Kiva and answering several questions about the data.
#
# - Use your hypothesis testing skills and the  ["Guide: Choosing the Right Hypothesis Test"](https://login.codingdojo.com/m/376/12533/88117) lesson from the LP.
#
#
# - Kiva Crowdfunding Data Set:
#     -  https://www.kaggle.com/datasets/kiva/data-science-for-good-kiva-crowdfunding

# %% [markdown]
# ### Questions to Answer

# %% [markdown]
# - Q1: Do all-male teams get more funding vs teams that include at least 1 female?
# - Q2: Do different sectors get more/less funding?

# %% [markdown]
# # Hypothesis Testing

# %%
import json
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
import scipy
scipy.__version__
# Out:
# '1.7.3'

# %%
## load the kiva_loans.csv. display info and head
df = pd.read_csv('../Data/kiva_loans.csv.gz')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 666984 entries, 0 to 666983
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  666984 non-null  int64
#  1   funded_amount       666984 non-null  float64
#  2   loan_amount         666984 non-null  float64
#  3   activity            666984 non-null  object
#  4   sector              666984 non-null  object
#  5   use                 666973 non-null  object
#  6   country_code        666976 non-null  object
#  7   country             666984 non-null  object
#  8   region              614405 non-null  object
#  9   currency            666984 non-null  object
#  10  partner_id          653896 non-null  float64
#  11  posted_time         666984 non-null  object
#  12  disbursed_time      665003 non-null  object
#  13  funded_time         619335 non-null  object
#  14  term_in_months      666984 non-null  float64
#  15  lender_count        666984 non-null  int64
#  16  tags                496877 non-null  object
#  17  borrower_genders    666984 non-null  object
#  18  repayment_interval  666984 non-null  object
#  19  date                666984 non-null  object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 101.8+ MB
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
#          region currency  partner_id                posted_time  \
# 0        Lahore      PKR       247.0  2014-01-01 06:12:39+00:00
# 1        Lahore      PKR       247.0  2014-01-01 06:51:08+00:00
# 2     Maynaguri      INR       334.0  2014-01-01 09:58:07+00:00
# 3        Lahore      PKR       247.0  2014-01-01 08:03:11+00:00
# 4  Abdul Hakeem      PKR       245.0  2014-01-01 11:53:19+00:00
#
#               disbursed_time                funded_time  term_in_months  \
# 0  2013-12-17 08:00:00+00:00  2014-01-02 10:06:32+00:00            12.0
# 1  2013-12-17 08:00:00+00:00  2014-01-02 09:17:23+00:00            11.0
# 2  2013-12-17 08:00:00+00:00  2014-01-01 16:01:36+00:00            43.0
# 3  2013-12-24 08:00:00+00:00  2014-01-01 13:00:00+00:00            11.0
# 4  2013-12-17 08:00:00+00:00  2014-01-01 19:18:51+00:00            14.0
#
#    lender_count                          tags borrower_genders  \
# 0            12                           NaN           female
# 1            14                           NaN   female, female
# 2             6  user_favorite, user_favorite           female
# 3             8                           NaN           female
# 4            16                           NaN           female
#
#   repayment_interval        date
# 0          irregular  2014-01-01
# 1          irregular  2014-01-01
# 2             bullet  2014-01-01
# 3          irregular  2014-01-01
# 4            monthly  2014-01-01

# %%
## Drop null values from related columns
df = df.dropna(subset=['borrower_genders','funded_amount'])

# Setting the id as the index
df = df.set_index('id')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 666984 entries, 653051 to 1340339
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   funded_amount       666984 non-null  float64
#  1   loan_amount         666984 non-null  float64
#  2   activity            666984 non-null  object
#  3   sector              666984 non-null  object
#  4   use                 666973 non-null  object
#  5   country_code        666976 non-null  object
#  6   country             666984 non-null  object
#  7   region              614405 non-null  object
#  8   currency            666984 non-null  object
#  9   partner_id          653896 non-null  float64
#  10  posted_time         666984 non-null  object
#  11  disbursed_time      665003 non-null  object
#  12  funded_time         619335 non-null  object
#  13  term_in_months      666984 non-null  float64
#  14  lender_count        666984 non-null  int64
#  15  tags                496877 non-null  object
#  16  borrower_genders    666984 non-null  object
#  17  repayment_interval  666984 non-null  object
#  18  date                666984 non-null  object
# dtypes: float64(4), int64(1), object(14)
# memory usage: 101.8+ MB
#         funded_amount  loan_amount             activity          sector  \
# id
# 653051          300.0        300.0  Fruits & Vegetables            Food
# 653053          575.0        575.0             Rickshaw  Transportation
# 653068          150.0        150.0       Transportation  Transportation
# 653063          200.0        200.0           Embroidery            Arts
# 653084          400.0        400.0           Milk Sales            Food
#
#                                                       use country_code  \
# id
# 653051            To buy seasonal, fresh fruits to sell.            PK
# 653053  to repair and maintain the auto rickshaw used ...           PK
# 653068  To repair their old cycle-van and buy another ...           IN
# 653063  to purchase an embroidery machine and a variet...           PK
# 653084                           to purchase one buffalo.           PK
#
#          country        region currency  partner_id  \
# id
# 653051  Pakistan        Lahore      PKR       247.0
# 653053  Pakistan        Lahore      PKR       247.0
# 653068     India     Maynaguri      INR       334.0
# 653063  Pakistan        Lahore      PKR       247.0
# 653084  Pakistan  Abdul Hakeem      PKR       245.0
#
#                       posted_time             disbursed_time  \
# id
# 653051  2014-01-01 06:12:39+00:00  2013-12-17 08:00:00+00:00
# 653053  2014-01-01 06:51:08+00:00  2013-12-17 08:00:00+00:00
# 653068  2014-01-01 09:58:07+00:00  2013-12-17 08:00:00+00:00
# 653063  2014-01-01 08:03:11+00:00  2013-12-24 08:00:00+00:00
# 653084  2014-01-01 11:53:19+00:00  2013-12-17 08:00:00+00:00
#
#                       funded_time  term_in_months  lender_count  \
# id
# 653051  2014-01-02 10:06:32+00:00            12.0            12
# 653053  2014-01-02 09:17:23+00:00            11.0            14
# 653068  2014-01-01 16:01:36+00:00            43.0             6
# 653063  2014-01-01 13:00:00+00:00            11.0             8
# 653084  2014-01-01 19:18:51+00:00            14.0            16
#
#                                 tags borrower_genders repayment_interval  \
# id
# 653051                           NaN           female          irregular
# 653053                           NaN   female, female          irregular
# 653068  user_favorite, user_favorite           female             bullet
# 653063                           NaN           female          irregular
# 653084                           NaN           female            monthly
#
#               date
# id
# 653051  2014-01-01
# 653053  2014-01-01
# 653068  2014-01-01
# 653063  2014-01-01
# 653084  2014-01-01

# %% [markdown]
# # Q1:  Do all-male teams get more funding vs teams that include at least 1 female?

# %% [markdown]
# ## 1. State the Hypothesis & Null Hypothesis

# %% [markdown]
# - $H_0$ (Null Hypothesis): There is no difference between funded amounts for teams with all males vs at least one female.
# - $H_A$ (Alternative Hypothesis):  There is a significant difference between funded amounts for teams with all males vs at least one female.

# %% [markdown]
# ## 2. Determine the correct test to perform.
# - Numerical Data
# - Two groups/samples
# - We want to run a 2-sample T-test.

# %% [markdown]
# ### Visualize and separate data for hypothesis

# %% [markdown]
# - What column is our target?
# - What column determines our groups?

# %%
## check the col that contains the measurement
df['funded_amount'].describe()
# Out:
# count    666984.000000
# mean        785.127844
# std        1127.999928
# min           0.000000
# 25%         250.000000
# 50%         450.000000
# 75%         900.000000
# max      100000.000000
# Name: funded_amount, dtype: float64

# %%
## check the col that contains info on gender
df['borrower_genders']#.describe()
# Out:
# id
# 653051             female
# 653053     female, female
# 653068             female
# 653063             female
# 653084             female
#                 ...
# 1340318            female
# 1340323            female
# 1340316            female
# 1340338            female
# 1340339            female
# Name: borrower_genders, Length: 666984, dtype: object

# %%
## create a column that easily separates our groups
df['has_female'] = df['borrower_genders'].str.contains('female')
df['has_female'].value_counts()
# Out:
# True     528461
# False    138523
# Name: has_female, dtype: int64

# %%
## save list of columns needed for each group
needed_cols = ['has_female','funded_amount']

df[needed_cols]
# Out:
#          has_female  funded_amount
# id
# 653051         True          300.0
# 653053         True          575.0
# 653068         True          150.0
# 653063         True          200.0
# 653084         True          400.0
# ...             ...            ...
# 1340318        True            0.0
# 1340323        True            0.0
# 1340316        True           25.0
# 1340338        True            0.0
# 1340339        True            0.0
#
# [666984 rows x 2 columns]

# %%
## save male team in separate variable
male_df = df.loc[ df['has_female']==False, needed_cols]
male_df
# Out:
#          has_female  funded_amount
# id
# 653418        False          450.0
# 653170        False         3175.0
# 653432        False          550.0
# 1080150       False          125.0
# 653410        False         1075.0
# ...             ...            ...
# 1339703       False            0.0
# 1339831       False           50.0
# 1339701       False          125.0
# 1339668       False          175.0
# 1339743       False            0.0
#
# [138523 rows x 2 columns]

# %%
## save female team in separate variables
female_df = df.loc[ df['has_female']==True, needed_cols]
female_df
# Out:
#          has_female  funded_amount
# id
# 653051         True          300.0
# 653053         True          575.0
# 653068         True          150.0
# 653063         True          200.0
# 653084         True          400.0
# ...             ...            ...
# 1340318        True            0.0
# 1340323        True            0.0
# 1340316        True           25.0
# 1340338        True            0.0
# 1340339        True            0.0
#
# [528461 rows x 2 columns]

# %%
## Make a df just for visualization by concat the groups 
plot_df = pd.concat([female_df,male_df])
plot_df
# Out:
#          has_female  funded_amount
# id
# 653051         True          300.0
# 653053         True          575.0
# 653068         True          150.0
# 653063         True          200.0
# 653084         True          400.0
# ...             ...            ...
# 1339703       False            0.0
# 1339831       False           50.0
# 1339701       False          125.0
# 1339668       False          175.0
# 1339743       False            0.0
#
# [666984 rows x 2 columns]

# %%
## visualize the group means
sns.barplot(data=plot_df, x='has_female',y='funded_amount')
# Out:
# <AxesSubplot:xlabel='has_female', ylabel='funded_amount'>

# %% [markdown]
# ## 3. Testing Assumptions

# %% [markdown]
# - No significant outliers
# - Normality
# - Equal Variance

# %% [markdown]
# ### Checking Assumption of No Sig. Outliers

# %%
## Saving JUST the numeric col as final group variables
male_group = male_df['funded_amount']
female_group = female_df['funded_amount']
male_group
# Out:
# id
# 653418      450.0
# 653170     3175.0
# 653432      550.0
# 1080150     125.0
# 653410     1075.0
#             ...
# 1339703       0.0
# 1339831      50.0
# 1339701     125.0
# 1339668     175.0
# 1339743       0.0
# Name: funded_amount, Length: 138523, dtype: float64

# %%
## Check female group for outliers
female_outliers = np.abs(stats.zscore(female_group)) > 3
female_outliers.sum()
# Out:
# 13344

# %%
## remove outliers from female_group
female_group = female_group.loc[~female_outliers]
female_group
# Out:
# id
# 653051     300.0
# 653053     575.0
# 653068     150.0
# 653063     200.0
# 653084     400.0
#            ...
# 1340318      0.0
# 1340323      0.0
# 1340316     25.0
# 1340338      0.0
# 1340339      0.0
# Name: funded_amount, Length: 515117, dtype: float64

# %%
## Check male group for outliers
male_outliers = np.abs(stats.zscore(male_group)) > 3
male_outliers.sum()
# Out:
# 1752

# %%
## remove outliers from female_group
male_group = male_group.loc[~male_outliers]
male_group
# Out:
# id
# 653418      450.0
# 653170     3175.0
# 653432      550.0
# 1080150     125.0
# 653410     1075.0
#             ...
# 1339703       0.0
# 1339831      50.0
# 1339701     125.0
# 1339668     175.0
# 1339743       0.0
# Name: funded_amount, Length: 136771, dtype: float64

# %% [markdown]
# ### Test for Normality

# %%
## Check female group for normality
result = stats.normaltest(female_group)
result.pvalue
# Out:
# 0.0

# %%
## Check n for female group
len(female_group)
# Out:
# 515117

# %%
## Check male group for normality
result = stats.normaltest(male_group)
result.pvalue
# Out:
# 0.0

# %%
## Check n for male group
len(male_group)
# Out:
# 136771

# %% [markdown]
# - We have large enough groups that we can safely disregard the assumption of normality.

# %% [markdown]
# ### Test for Equal Variances

# %%
## Use Levene's test for equal variance
result = stats.levene(male_group, female_group)
print(result)
# Out:
# LeveneResult(statistic=59.19804480808947, pvalue=1.427735962793746e-14)

# %%
## Use an if-else to help interpret the p-value
if result.pvalue < .05:
    print(f"The groups do NOT have equal variance.")
else:
    print(f"The groups DO have equal variance.")
# Out:
# The groups do NOT have equal variance.

# %% [markdown]
# - We met the assumption of normality but did NOT meet the assumption of equal variance.
# - We will therefore run a Welch's t-test instead by adding `equal_var=False` to `stats.ttest_ind`

# %% [markdown]
# ## Final Hypothesis Test - Welch's T-Test

# %%
result = stats.ttest_ind(male_group, female_group, equal_var=False)
print(result)
result.pvalue  < .05
# Out:
# Ttest_indResult(statistic=29.74961820258417, pvalue=4.102857297759938e-194)
# True

# %%
male_group.mean()
# Out:
# 709.4942275774836

# %%
female_group.mean()
# Out:
# 652.9337897992107

# %% [markdown]
# We had a p-value < .05 for our welch's t-test. We reject the null hypothesis and support the alternative that teams with at least one female receive smaller funded amounts.

# %% [markdown]
# # Q2: Do different sectors get more/less funding?

# %% [markdown]
# ## 1. State the Hypothesis & Null Hypothesis

# %% [markdown]
# - $H_0$ (Null Hypothesis): There is no difference between funded amounts for different sectors.
# - $H_A$ (Alternative Hypothesis):  There is a significant difference between funded amounts for different sectors.

# %% [markdown]
# ## 2. Determine the correct test to perform.

# %% [markdown]
# - Numerical Data
# - More than two groups/samples
# - We want to run an ANOVA test.

# %%
df['sector'].value_counts()
# Out:
# Agriculture       179224
# Food              135749
# Retail            123758
# Services           44699
# Personal Use       36247
# Housing            33571
# Clothing           32480
# Education          30837
# Transportation     15455
# Arts               11994
# Health              9172
# Construction        6194
# Manufacturing       6158
# Entertainment        820
# Wholesale            626
# Name: sector, dtype: int64

# %% [markdown]
# ### Visualize and separate data for hypothesis

# %% [markdown]
# - What column is our target?
# - What column determines our groups?

# %%
ax = sns.barplot(data=df, x='sector', y='funded_amount')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');

# %%
needed_cols = ['sector','funded_amount']
df[needed_cols]
# Out:
#                  sector  funded_amount
# id
# 653051             Food          300.0
# 653053   Transportation          575.0
# 653068   Transportation          150.0
# 653063             Arts          200.0
# 653084             Food          400.0
# ...                 ...            ...
# 1340318     Agriculture            0.0
# 1340323     Agriculture            0.0
# 1340316     Agriculture           25.0
# 1340338     Agriculture            0.0
# 1340339     Agriculture            0.0
#
# [666984 rows x 2 columns]

# %%
## Create a dictionary with each group as key and funded_amount as values
groups ={}

for sector in df['sector'].unique():
    temp = df.loc[df['sector']== sector, 'funded_amount']
    groups[sector] = temp

groups.keys()
# Out:
# dict_keys(['Food', 'Transportation', 'Arts', 'Services', 'Agriculture', 'Manufacturing', 'Wholesale', 'Retail', 'Clothing', 'Construction', 'Health', 'Education', 'Personal Use', 'Housing', 'Entertainment'])

# %%
groups['Personal Use']
# Out:
# id
# 653432      550.0
# 653188     1000.0
# 653191     1500.0
# 653186     1000.0
# 653215      450.0
#             ...
# 1336305       0.0
# 1336340       0.0
# 1336479       0.0
# 1336868       0.0
# 1337940       0.0
# Name: funded_amount, Length: 36247, dtype: float64

# %% [markdown]
# ## 3. Testing Assumptions

# %% [markdown]
# - No significant outliers
# - Normality
# - Equal Variance

# %% [markdown]
# ### Checking Assumption of No Sig. Outliers

# %%
## Loop through groups dict
for sector, data in groups.items():

    ## determine if there are any outliers
    outliers = np.abs(stats.zscore(data)) > 3
    
    ## print a statement about how many outliers for which group name
    print(f"There were {outliers.sum()} outliers in the {sector} group.")

    ## Remove the outiers from data and overwrite the sector data in the dict
    data = data.loc[~outliers]
    groups[sector] = data
# Out:
# There were 3994 outliers in the Food group.
# There were 231 outliers in the Transportation group.
# There were 273 outliers in the Arts group.
# There were 1253 outliers in the Services group.
# There were 2478 outliers in the Agriculture group.
# There were 95 outliers in the Manufacturing group.
# There were 4 outliers in the Wholesale group.
# There were 3007 outliers in the Retail group.
# There were 857 outliers in the Clothing group.
# There were 151 outliers in the Construction group.
# There were 109 outliers in the Health group.
# There were 473 outliers in the Education group.
# There were 563 outliers in the Personal Use group.
# There were 590 outliers in the Housing group.
# There were 17 outliers in the Entertainment group.

# %% [markdown]
# ### Test for Normality

# %%
## Running normal test on each group and confirming there are >20 in each group

## Save a list with an inner list of column names
norm_results = [['group','n','pval','sig?']]


## loop through group dict
for sector, data in groups.items():
    ## calculate normaltest results
    stat, p = stats.normaltest(data)
    
    ## Append the right info into norm_resutls (as a list)
    norm_results.append([sector,len(data), p, p<.05])
    
    
## Make norm_results a dataframe (first row is columns, everything else data)
normal_results = pd.DataFrame(norm_results[1:], columns = norm_results[0])
normal_results
# Out:
#              group       n          pval  sig?
# 0             Food  131755  0.000000e+00  True
# 1   Transportation   15224  0.000000e+00  True
# 2             Arts   11721  0.000000e+00  True
# 3         Services   43446  0.000000e+00  True
# 4      Agriculture  176746  0.000000e+00  True
# 5    Manufacturing    6063  0.000000e+00  True
# 6        Wholesale     622  6.931789e-92  True
# 7           Retail  120751  0.000000e+00  True
# 8         Clothing   31623  0.000000e+00  True
# 9     Construction    6043  0.000000e+00  True
# 10          Health    9063  0.000000e+00  True
# 11       Education   30364  0.000000e+00  True
# 12    Personal Use   35684  0.000000e+00  True
# 13         Housing   32981  0.000000e+00  True
# 14   Entertainment     803  2.434681e-72  True

# %% [markdown]
# - We failed the assumption of normality, but our groups are large enough that we can safely disregard/ignore the assumption of normality.

# %% [markdown]
# ### Test for Equal Variances

# %%
## DEMO: using the * operator to unpack lists
a_list = ['a','b','c']
b_list = [1,2,3]

new_list =[*a_list, *b_list]
new_list
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
## Use Levene's test for equal variance
result = stats.levene(*groups.values())
print(result)
# Out:
# LeveneResult(statistic=941.8381341090084, pvalue=0.0)

# %%
## Use an if-else to help interpret the p-value
if result.pvalue < .05:
    print(f"The groups do NOT have equal variance.")
else:
    print(f"The groups DO have equal variance.")
# Out:
# The groups do NOT have equal variance.

# %% [markdown]
# - We met the assumption of normality but did NOT meet the assumption of equal variance.
# - We wanted to run an ANOVA test but will need to use a Kurskal-Wallis test instead.

# %% [markdown]
# ## Final Hypothesis Test

# %%
## Running Krukal Test for Original Hypothesis
result = stats.kruskal(*groups.values())
print(result)
result.pvalue<.05
# Out:
# KruskalResult(statistic=36348.9897834356, pvalue=0.0)
# True

# %% [markdown]
# - Our Kruskal Wallis test returned a p-value MUCH less than .05. We reject the null hypothesis and conclude that there is a significant difference between funded amounts for different Sectors.
#
# - We don't know WHICH sectors are different yet, though....
#     - For that we will run a Post-Hoc Multiple Comparison Test to get a p-value for every possible combination of 2 groups.

# %% [markdown]
# ### Post-Hoc Multiple Comparison Test

# %%
## Post Hoc
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %% [markdown]
# #### Testing Converting our Dictionary to a DataFrame

# %%
## slice a test sector
temp = groups['Personal Use']
temp
# Out:
# id
# 653432      550.0
# 653188     1000.0
# 653191     1500.0
# 653186     1000.0
# 653215      450.0
#             ...
# 1336305       0.0
# 1336340       0.0
# 1336479       0.0
# 1336868       0.0
# 1337940       0.0
# Name: funded_amount, Length: 35684, dtype: float64

# %%
## test making a datafrae from the test sector and filling in the sector name
pd.DataFrame({'Funded Amount':temp, 'Sector':'Personal Use'})
# Out:
#          Funded Amount        Sector
# id
# 653432           550.0  Personal Use
# 653188          1000.0  Personal Use
# 653191          1500.0  Personal Use
# 653186          1000.0  Personal Use
# 653215           450.0  Personal Use
# ...                ...           ...
# 1336305            0.0  Personal Use
# 1336340            0.0  Personal Use
# 1336479            0.0  Personal Use
# 1336868            0.0  Personal Use
# 1337940            0.0  Personal Use
#
# [35684 rows x 2 columns]

# %% [markdown]
# #### Preparing the new dataframe for Tukey's test in a looop

# %%
## make a list for saving the dataframes to
tukeys_dfs = []

## Loop through groups dict's items
for sector, temp in groups.items():
    
    ## make a temp_df with the data and the sector name
    temp_df = pd.DataFrame({'Funded Amount':temp, 'Sector':sector})
    
    ## append to tukeys_dfs
    tukeys_dfs.append(temp_df)
    
## concatenate them into 1 dataframe    
tukeys_data = pd.concat(tukeys_dfs)
tukeys_data
# Out:
#          Funded Amount         Sector
# id
# 653051           300.0           Food
# 653084           400.0           Food
# 653048           625.0           Food
# 653065           250.0           Food
# 653055           350.0           Food
# ...                ...            ...
# 1325258         1400.0  Entertainment
# 1326378          300.0  Entertainment
# 1331821          350.0  Entertainment
# 1337050          100.0  Entertainment
# 1340264            0.0  Entertainment
#
# [652889 rows x 2 columns]

# %%
## save the values as kg_lost and the labels to the Diet
values = tukeys_data['Funded Amount']
labels = tukeys_data['Sector']

## perform tukey's multiple comparison test and display the summary
tukeys_results = pairwise_tukeyhsd(values,labels)
tukeys_results.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
## optional -slicing out dataframe from results
summary = tukeys_results.summary()
tukeys_df = pd.DataFrame(summary.data[1:], columns=summary.data[0])
tukeys_df
# Out:
#              group1          group2  meandiff  p-adj     lower     upper  \
# 0       Agriculture            Arts  165.1053    0.0  143.2289  186.9817
# 1       Agriculture        Clothing  235.2757    0.0  221.2716  249.2798
# 2       Agriculture    Construction  177.9816    0.0  147.9769  207.9863
# 3       Agriculture       Education  213.7211    0.0  199.4728  227.9693
# 4       Agriculture   Entertainment  404.3165    0.0  323.1940  485.4390
# ..              ...             ...       ...    ...       ...       ...
# 100          Retail  Transportation  -36.3701    0.0  -56.0959  -16.6443
# 101          Retail       Wholesale  629.3854    0.0  537.1845  721.5863
# 102        Services  Transportation -224.1958    0.0 -245.7973 -202.5943
# 103        Services       Wholesale  441.5597    0.0  348.9394  534.1800
# 104  Transportation       Wholesale  665.7555    0.0  571.9313  759.5797
#
#      reject
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# ..      ...
# 100    True
# 101    True
# 102    True
# 103    True
# 104    True
#
# [105 rows x 7 columns]

# %%
pd.set_option('display.max_rows',120)
tukeys_df
# Out:
#              group1          group2  meandiff   p-adj     lower     upper  \
# 0       Agriculture            Arts  165.1053  0.0000  143.2289  186.9817
# 1       Agriculture        Clothing  235.2757  0.0000  221.2716  249.2798
# 2       Agriculture    Construction  177.9816  0.0000  147.9769  207.9863
# 3       Agriculture       Education  213.7211  0.0000  199.4728  227.9693
# 4       Agriculture   Entertainment  404.3165  0.0000  323.1940  485.4390
# 5       Agriculture            Food   14.7386  0.0000    6.3906   23.0867
# 6       Agriculture          Health  236.1670  0.0000  211.4647  260.8693
# 7       Agriculture         Housing  -87.0379  0.0000 -100.7953  -73.2806
# 8       Agriculture   Manufacturing   96.7218  0.0000   66.7650  126.6786
# 9       Agriculture    Personal Use -327.2873  0.0000 -340.5983 -313.9763
# 10      Agriculture          Retail  -70.8510  0.0000  -79.4141  -62.2878
# 11      Agriculture        Services  116.9748  0.0000  104.6928  129.2567
# 12      Agriculture  Transportation -107.2211  0.0000 -126.5938  -87.8483
# 13      Agriculture       Wholesale  558.5345  0.0000  466.4084  650.6605
# 14             Arts        Clothing   70.1704  0.0000   45.3679   94.9729
# 15             Arts    Construction   12.8763  0.9973  -23.4463   49.1989
# 16             Arts       Education   48.6158  0.0000   23.6746   73.5569
# 17             Arts   Entertainment  239.2112  0.0000  155.5458  322.8767
# 18             Arts            Food -150.3667  0.0000 -172.4741 -128.2592
# 19             Arts          Health   71.0617  0.0000   38.9797  103.1436
# 20             Arts         Housing -252.1432  0.0000 -276.8073 -227.4792
# 21             Arts   Manufacturing  -68.3835  0.0000 -104.6665  -32.1005
# 22             Arts    Personal Use -492.3926  0.0000 -516.8105 -467.9748
# 23             Arts          Retail -235.9563  0.0000 -258.1458 -213.7667
# 24             Arts        Services  -48.1305  0.0000  -72.0030  -24.2581
# 25             Arts  Transportation -272.3263  0.0000 -300.5106 -244.1421
# 26             Arts       Wholesale  393.4292  0.0000  299.0562  487.8021
# 27         Clothing    Construction  -57.2941  0.0000  -89.4945  -25.0937
# 28         Clothing       Education  -21.5546  0.0064  -39.9829   -3.1264
# 29         Clothing   Entertainment  169.0408  0.0000   87.0808  251.0009
# 30         Clothing            Food -220.5371  0.0000 -234.8995 -206.1747
# 31         Clothing          Health    0.8913  1.0000  -26.4362   28.2188
# 32         Clothing         Housing -322.3136  0.0000 -340.3650 -304.2622
# 33         Clothing   Manufacturing -138.5539  0.0000 -170.7097 -106.3981
# 34         Clothing    Personal Use -562.5630  0.0000 -580.2766 -544.8494
# 35         Clothing          Retail -306.1266  0.0000 -320.6151 -291.6382
# 36         Clothing        Services -118.3009  0.0000 -135.2548 -101.3471
# 37         Clothing  Transportation -342.4967  0.0000 -365.1218 -319.8717
# 38         Clothing       Wholesale  323.2588  0.0000  230.3944  416.1231
# 39     Construction       Education   35.7395  0.0146    3.4321   68.0468
# 40     Construction   Entertainment  226.3349  0.0000  140.1861  312.4837
# 41     Construction            Food -163.2430  0.0000 -193.4165 -133.0694
# 42     Construction          Health   58.1854  0.0000   20.0939   96.2768
# 43     Construction         Housing -265.0195  0.0000 -297.1134 -232.9257
# 44     Construction   Manufacturing  -81.2598  0.0000 -122.9511  -39.5686
# 45     Construction    Personal Use -505.2689  0.0000 -537.1740 -473.3638
# 46     Construction          Retail -248.8326  0.0000 -279.0663 -218.5988
# 47     Construction        Services  -61.0069  0.0000  -92.4965  -29.5172
# 48     Construction  Transportation -285.2027  0.0000 -320.0747 -250.3306
# 49     Construction       Wholesale  380.5528  0.0000  283.9715  477.1342
# 50        Education   Entertainment  190.5955  0.0000  108.5934  272.5976
# 51        Education            Food -198.9825  0.0000 -213.5830 -184.3819
# 52        Education          Health   22.4459  0.2616   -5.0075   49.8993
# 53        Education         Housing -300.7590  0.0000 -319.0005 -282.5176
# 54        Education   Manufacturing -116.9993  0.0000 -149.2622  -84.7364
# 55        Education    Personal Use -541.0084  0.0000 -558.9156 -523.1012
# 56        Education          Retail -284.5720  0.0000 -299.2966 -269.8474
# 57        Education        Services  -96.7463  0.0000 -113.9024  -79.5902
# 58        Education  Transportation -320.9421  0.0000 -343.7191 -298.1651
# 59        Education       Wholesale  344.8134  0.0000  251.9119  437.7149
# 60    Entertainment            Food -389.5779  0.0000 -470.7630 -308.3928
# 61    Entertainment          Health -168.1496  0.0000 -252.5980  -83.7011
# 62    Entertainment         Housing -491.3545  0.0000 -573.2727 -409.4362
# 63    Entertainment   Manufacturing -307.5947  0.0000 -393.7269 -221.4626
# 64    Entertainment    Personal Use -731.6039  0.0000 -813.4483 -649.7594
# 65    Entertainment          Retail -475.1675  0.0000 -556.3750 -393.9600
# 66    Entertainment        Services -287.3418  0.0000 -369.0252 -205.6584
# 67    Entertainment  Transportation -511.5376  0.0000 -594.5836 -428.4916
# 68    Entertainment       Wholesale  154.2179  0.0018   31.7086  276.7273
# 69             Food          Health  221.4283  0.0000  196.5212  246.3355
# 70             Food         Housing -101.7766  0.0000 -115.8985  -87.6547
# 71             Food   Manufacturing   81.9832  0.0000   51.8572  112.1091
# 72             Food    Personal Use -342.0260  0.0000 -355.7134 -328.3385
# 73             Food          Retail  -85.5896  0.0000  -94.7270  -76.4522
# 74             Food        Services  102.2361  0.0000   89.5472  114.9250
# 75             Food  Transportation -121.9597  0.0000 -141.5930 -102.3263
# 76             Food       Wholesale  543.7958  0.0000  451.6146  635.9770
# 77           Health         Housing -323.2049  0.0000 -350.4068 -296.0030
# 78           Health   Manufacturing -139.4452  0.0000 -177.4989 -101.3915
# 79           Health    Personal Use -563.4543  0.0000 -590.4332 -536.4754
# 80           Health          Retail -307.0179  0.0000 -331.9980 -282.0378
# 81           Health        Services -119.1922  0.0000 -145.6785  -92.7060
# 82           Health  Transportation -343.3880  0.0000 -373.8180 -312.9581
# 83           Health       Wholesale  322.3675  0.0000  227.2997  417.4353
# 84          Housing   Manufacturing  183.7597  0.0000  151.7106  215.8089
# 85          Housing    Personal Use -240.2494  0.0000 -257.7686 -222.7302
# 86          Housing          Retail   16.1870  0.0100    1.9368   30.4371
# 87          Housing        Services  204.0127  0.0000  187.2621  220.7633
# 88          Housing  Transportation  -20.1831  0.1361  -42.6563    2.2901
# 89          Housing       Wholesale  645.5724  0.0000  552.7449  738.3999
# 90    Manufacturing    Personal Use -424.0091  0.0000 -455.8692 -392.1490
# 91    Manufacturing          Retail -167.5727  0.0000 -197.7590 -137.3865
# 92    Manufacturing        Services   20.2530  0.6764  -11.1911   51.6970
# 93    Manufacturing  Transportation -203.9428  0.0000 -238.7737 -169.1120
# 94    Manufacturing       Wholesale  461.8127  0.0000  365.2462  558.3792
# 95     Personal Use          Retail  256.4364  0.0000  242.6166  270.2561
# 96     Personal Use        Services  444.2621  0.0000  427.8761  460.6481
# 97     Personal Use  Transportation  220.0663  0.0000  197.8635  242.2690
# 98     Personal Use       Wholesale  885.8218  0.0000  793.0594  978.5842
# 99           Retail        Services  187.8257  0.0000  174.9942  200.6572
# 100          Retail  Transportation  -36.3701  0.0000  -56.0959  -16.6443
# 101          Retail       Wholesale  629.3854  0.0000  537.1845  721.5863
# 102        Services  Transportation -224.1958  0.0000 -245.7973 -202.5943
# 103        Services       Wholesale  441.5597  0.0000  348.9394  534.1800
# 104  Transportation       Wholesale  665.7555  0.0000  571.9313  759.5797
#
#      reject
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31    False
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51     True
# 52    False
# 53     True
# 54     True
# 55     True
# 56     True
# 57     True
# 58     True
# 59     True
# 60     True
# 61     True
# 62     True
# 63     True
# 64     True
# 65     True
# 66     True
# 67     True
# 68     True
# 69     True
# 70     True
# 71     True
# 72     True
# 73     True
# 74     True
# 75     True
# 76     True
# 77     True
# 78     True
# 79     True
# 80     True
# 81     True
# 82     True
# 83     True
# 84     True
# 85     True
# 86     True
# 87     True
# 88    False
# 89     True
# 90     True
# 91     True
# 92    False
# 93     True
# 94     True
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# 100    True
# 101    True
# 102    True
# 103    True
# 104    True

# %%
## make a barplot of final data to go with results
ax = sns.barplot(data=tukeys_data, x='Sector', y='Funded Amount', ci=68)
ax.set_xticklabels(ax.get_xticklabels(), rotation='45', ha='right');

# %%
## Not significantly different
tukeys_df[tukeys_df['reject'] ==False]
# Out:
#            group1          group2  meandiff   p-adj    lower    upper  reject
# 15           Arts    Construction   12.8763  0.9973 -23.4463  49.1989   False
# 31       Clothing          Health    0.8913  1.0000 -26.4362  28.2188   False
# 52      Education          Health   22.4459  0.2616  -5.0075  49.8993   False
# 88        Housing  Transportation  -20.1831  0.1361 -42.6563   2.2901   False
# 92  Manufacturing        Services   20.2530  0.6764 -11.1911  51.6970   False

# %%
## also can use built-in plot tukeys_reuslts.plot_simultaneous
tukeys_results.plot_simultaneous();

# %% [markdown]
# - As we can see, there are MANY sectors that are significantly different from each other. Some highlights include that Wholesame and Entertainment have the highest average funded amounts and Personal use has the lowest.

# %% [markdown]
# # APPENDIX

# %%
raise Exception('Stop here!')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 raise Exception('Stop here!')
#
# Exception: Stop here!

# %% [markdown]
# ## Q1

# %% [markdown]
# #### OPTIONAL: visualize cleaned groups

# %%
## combine all of the indices from male_group and female_group into 1 list
combined_ids = [*male_group.index,*female_group.index]
combined_ids[:5]

# %%
## create a clean version of plot_df by only keeping
plot_df = plot_df[plot_df.index.isin(combined_ids)]
plot_df

# %%
sns.barplot(data=plot_df, x='has_female',y='funded_amount')

# %% [markdown]
# ## Q2

# %%
## concatenate and fix index
plot_df = pd.concat(groups)
plot_df

# %%
## Fix index (only want 'id') (option A)
plot_df = plot_df.reset_index().set_index('id')
plot_df = plot_df.drop(columns='level_0')
plot_df

# %%
## Fix index (only want 'id') (option B)
plot_df = pd.concat(groups)
plot_df = plot_df.droplevel(0)
plot_df

# %%
ax = sns.barplot(data=plot_df, x='sector', y='funded_amount')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right');
